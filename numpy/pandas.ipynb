# %%
import pandas as pd

# %%
s = pd.Series([1,4,5,6])
print(s)
print(type(s))
# Out:
# 0    1
# 1    4
# 2    5
# 3    6
# dtype: int64
# <class 'pandas.core.series.Series'>

# %%
print(s[0])
# Out:
# 1

# %%
s.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
s2 = pd.Series([23, 24, 25, 26], index = ["Adam", "Eve", "Charlie", "Bob"])
print(s2)
print(s2["Eve"])
# Out:
# Adam       23
# Eve        24
# Charlie    25
# Bob        26
# dtype: int64
# 24

# %%
s1 = pd.Series([1, 2, 3])  
s2 = pd.Series([4, 5, 6])
s3=s1+s2
print(s3)
# Out:
# 0    5
# 1    7
# 2    9
# dtype: int64

# %%
s = pd.Series([1, 2, 3, 4, 5]) 
s[0]= 100
changed_s = s.drop(1)
changed_s
# Out:
# 0    100
# 2      3
# 3      4
# 4      5
# dtype: int64

# %%
info = {  
"Name" : ["Adam", "Eve", "Bob"],  
"Marks" : [78, 99, 85],  
"Grade" : ['B', 'O', 'A']  
}  

df = pd.DataFrame(info)
df
# Out:
#    Name  Marks Grade
# 0  Adam     78     B
# 1   Eve     99     O
# 2   Bob     85     A

# %%
print(type(df))
print(df.index)
print(df.columns)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex(start=0, stop=3, step=1)
# Index(['Name', 'Marks', 'Grade'], dtype='object')

# %%
import numpy as np
n2 = np.array([[3,45,56], [23,67,78]])
n2
# Out:
# array([[ 3, 45, 56],
#        [23, 67, 78]])

# %%
df2 = pd.DataFrame(n2 , columns = ["n1", "n2" , "n3"])
df2
# Out:
#    n1  n2  n3
# 0   3  45  56
# 1  23  67  78

# %%
l = [["Adam", 96], ["Eve", 75], ["Bob", 82], ["Charlie", 92]]
l
# Out:
# [['Adam', 96], ['Eve', 75], ['Bob', 82], ['Charlie', 92]]

# %%
df3 = pd.DataFrame(l, columns = ["name" , "marks"])
df3
# Out:
#       name  marks
# 0     Adam     96
# 1      Eve     75
# 2      Bob     82
# 3  Charlie     92

# %%
import pandas as pd
data_csv = pd.read_csv("raw_data.csv")
data_csv
# Out:
#     id          name   age country   gender   income
# 0    1      John Doe  29.0     USA     Male  55000.0
# 1    1      John Doe  29.0     USA     Male  55000.0
# 2    2    Jane Smith   NaN  Canada   Female  62000.0
# 3    3          Alex   NaN     USA  Unknown  47000.0
# 4    4  Maria Garcia  34.0   Spain   Female      NaN
# 5    5        Li Wei  27.0   China     Male  51000.0
# 6    6           NaN  45.0   India   Female  73000.0
# 7    7    Ahmed Khan  38.0     NaN     Male  68000.0
# 8    8    Rachel Lee  29.0     USA   Female  62000.0
# 9    9   Carlos Ruiz   NaN  Mexico     Male  45000.0
# 10  10   Emily Davis  31.0     USA      NaN  58000.0

# %%
import pandas as pd
json_data = pd.read_json("data.json")
json_data
# Out:
#      name  age        city
# 0  Sowham   20     Kolkata
# 1  Kushal   19  Jalpaiguri
# 2   Rohan   21    Durgapur

# %%
json_data.to_csv("output.csv")

# %%
import pandas as pd
df = pd.read_csv("employee_data.csv")
df
# Out:
#    ID     Name  Age Department  Salary
# 0   1    Alice   25         HR   55000
# 1   2      Bob   32         IT   72000
# 2   3  Charlie   28    Finance   48000
# 3   4    David   45  Marketing   91000
# 4   5      Eva   38         IT   65000
# 5   6    Frank   29    Finance   50000
# 6   7    Grace   41         HR   82000
# 7   8   Hannah   26  Marketing   47000
# 8   9      Ian   35         IT   75000
# 9  10    Julia   30    Finance   60000

# %%
df.head()
# Out:
#    ID     Name  Age Department  Salary
# 0   1    Alice   25         HR   55000
# 1   2      Bob   32         IT   72000
# 2   3  Charlie   28    Finance   48000
# 3   4    David   45  Marketing   91000
# 4   5      Eva   38         IT   65000

# %%
df.tail()
# Out:
#    ID    Name  Age Department  Salary
# 5   6   Frank   29    Finance   50000
# 6   7   Grace   41         HR   82000
# 7   8  Hannah   26  Marketing   47000
# 8   9     Ian   35         IT   75000
# 9  10   Julia   30    Finance   60000

# %%
df.sample()
# Out:
#    ID   Name  Age Department  Salary
# 0   1  Alice   25         HR   55000

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ID          10 non-null     int64
#  1   Name        10 non-null     str
#  2   Age         10 non-null     int64
#  3   Department  10 non-null     str
#  4   Salary      10 non-null     int64
# dtypes: int64(3), str(2)
# memory usage: 628.0 bytes

# %%
df.describe()
# Out:
#              ID        Age        Salary
# count  10.00000  10.000000     10.000000
# mean    5.50000  32.900000  64500.000000
# std     3.02765   6.674162  15182.226451
# min     1.00000  25.000000  47000.000000
# 25%     3.25000  28.250000  51250.000000
# 50%     5.50000  31.000000  62500.000000
# 75%     7.75000  37.250000  74250.000000
# max    10.00000  45.000000  91000.000000

# %%
df.nunique()
# Out:
# ID            10
# Name          10
# Age           10
# Department     4
# Salary        10
# dtype: int64

# %%
print(df.shape)
print(df.dtypes)
print(df.columns)
# Out:
# (10, 5)
# ID            int64
# Name            str
# Age           int64
# Department      str
# Salary        int64
# dtype: object
# Index(['ID', 'Name', 'Age', 'Department', 'Salary'], dtype='str')

# %%
df["Age"]
# Out:
# 0    25
# 1    32
# 2    28
# 3    45
# 4    38
# 5    29
# 6    41
# 7    26
# 8    35
# 9    30
# Name: Age, dtype: int64

# %%
df[["ID", "Age"]]
# Out:
#    ID  Age
# 0   1   25
# 1   2   32
# 2   3   28
# 3   4   45
# 4   5   38
# 5   6   29
# 6   7   41
# 7   8   26
# 8   9   35
# 9  10   30

# %%
df.loc[0]
# Out:
# ID                1
# Name          Alice
# Age              25
# Department       HR
# Salary        55000
# Name: 0, dtype: object

# %%
df.loc[0:3]
# Out:
#    ID     Name  Age Department  Salary
# 0   1    Alice   25         HR   55000
# 1   2      Bob   32         IT   72000
# 2   3  Charlie   28    Finance   48000
# 3   4    David   45  Marketing   91000

# %%
df.iloc[0:3]
# Out:
#    ID     Name  Age Department  Salary
# 0   1    Alice   25         HR   55000
# 1   2      Bob   32         IT   72000
# 2   3  Charlie   28    Finance   48000

# %%
df.loc[0 , "Name"]
# Out:
# 'Alice'

# %%
df.at[0 , "Name" ]
# Out:
# 'Alice'

# %%
df.iat[0, 1]
# Out:
# 'Alice'

# %%
print(df[df["Age"] > 30] )

df[(df['Age'] > 30) & (df['Salary'] > 50000)]
# Out:
#    ID   Name  Age Department  Salary
# 1   2    Bob   32         IT   72000
# 3   4  David   45  Marketing   91000
# 4   5    Eva   38         IT   65000
# 6   7  Grace   41         HR   82000
# 8   9    Ian   35         IT   75000
#    ID   Name  Age Department  Salary
# 1   2    Bob   32         IT   72000
# 3   4  David   45  Marketing   91000
# 4   5    Eva   38         IT   65000
# 6   7  Grace   41         HR   82000
# 8   9    Ian   35         IT   75000

# %%
Name = "Bob"
df.query(" Age > 30")
df.query("Age > 30 and Name == @Name")
# Out:
#    ID Name  Age Department  Salary
# 1   2  Bob   32         IT   72000

# %%
#cleaning data
df2 = pd.read_csv("raw_data.csv")
# handle missing values
# Out:
#     id          name   age country   gender   income
# 0    1      John Doe  29.0     USA     Male  55000.0
# 1    1      John Doe  29.0     USA     Male  55000.0
# 2    2    Jane Smith   NaN  Canada   Female  62000.0
# 3    3          Alex   NaN     USA  Unknown  47000.0
# 4    4  Maria Garcia  34.0   Spain   Female      NaN
# 5    5        Li Wei  27.0   China     Male  51000.0
# 6    6           NaN  45.0   India   Female  73000.0
# 7    7    Ahmed Khan  38.0     NaN     Male  68000.0
# 8    8    Rachel Lee  29.0     USA   Female  62000.0
# 9    9   Carlos Ruiz   NaN  Mexico     Male  45000.0
# 10  10   Emily Davis  31.0     USA      NaN  58000.0

# %%
df2.isnull()           # True for null values (NaN)
df2.isnull().sum()      # counts missing vals per column
df2.dropna()
df2.dropna(axis = 1)          # drops columns with missing values
df2.fillna(30)             # fill the nan with value
df2["age"].fillna(df2["age"].mean())

print(df2.ffill())             # forward fill
print(df2.bfill())             # backward fill
# Out:
#     id          name   age country   gender   income
# 0    1      John Doe  29.0     USA     Male  55000.0
# 1    1      John Doe  29.0     USA     Male  55000.0
# 2    2    Jane Smith  29.0  Canada   Female  62000.0
# 3    3          Alex  29.0     USA  Unknown  47000.0
# 4    4  Maria Garcia  34.0   Spain   Female  47000.0
# 5    5        Li Wei  27.0   China     Male  51000.0
# 6    6        Li Wei  45.0   India   Female  73000.0
# 7    7    Ahmed Khan  38.0   India     Male  68000.0
# 8    8    Rachel Lee  29.0     USA   Female  62000.0
# 9    9   Carlos Ruiz  29.0  Mexico     Male  45000.0
# 10  10   Emily Davis  31.0     USA     Male  58000.0
#     id          name   age country   gender   income
# 0    1      John Doe  29.0     USA     Male  55000.0
# 1    1      John Doe  29.0     USA     Male  55000.0
# 2    2    Jane Smith  34.0  Canada   Female  62000.0
# 3    3          Alex  34.0     USA  Unknown  47000.0
# 4    4  Maria Garcia  34.0   Spain   Female  51000.0
# ...

# %%
#handle dupplicate values

df3 = pd.read_csv("raw_data.csv")
df3.duplicated()
df3.duplicated("country")
df3.duplicated(["country", "gender"]) 
df3.drop_duplicates()
# Out:
#     id          name   age country   gender   income
# 0    1      John Doe  29.0     USA     Male  55000.0
# 2    2    Jane Smith   NaN  Canada   Female  62000.0
# 3    3          Alex   NaN     USA  Unknown  47000.0
# 4    4  Maria Garcia  34.0   Spain   Female      NaN
# 5    5        Li Wei  27.0   China     Male  51000.0
# 6    6           NaN  45.0   India   Female  73000.0
# 7    7    Ahmed Khan  38.0     NaN     Male  68000.0
# 8    8    Rachel Lee  29.0     USA   Female  62000.0
# 9    9   Carlos Ruiz   NaN  Mexico     Male  45000.0
# 10  10   Emily Davis  31.0     USA      NaN  58000.0

# %%
#handle datatypes
df = pd.read_csv("raw_data.csv") 
df.dtypes
df2 = df.fillna(0).copy()
df2.dtypes
df2["income"]= df2["income"].astype('int64')
df2["income"].dtype
# Out:
# dtype('int64')

# %%
df2["name"].str.lower()
df2["name"].str.upper()
df2["gender"].str.capitalize()                 # capitalize
df2["name"].str.split(" ")                     # splits into lists based on separator value 
type(df2["name"].str.split(" ")[0])            

df2["country"].str.contains("US")
df2["country"].str.contains("india", case=False)
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6      True
# 7       NaN
# 8     False
# 9     False
# 10    False
# Name: country, dtype: object

# %%
 #Transformation / Feature Engineering
import pandas as pd
df3 = pd.read_csv("raw_data.csv")
#apply method  to apply method
df3["tax"]= df3["income"].apply(lambda x : "10%" if x < 60000 else "20%")
#map method  modify
new_gender_vals = {"Male": "M", "Female": "F", "Unknown": "U"}
df3["gender"]= df3["gender"].map(new_gender_vals)
#assign method  to add new column

df3 = df3.assign(new_col= df3["income"] *1.1)

#replace 
df3["country"]= df3["country"].replace("USA" , "America")

# %%
df2 = pd.read_csv("raw_data.csv")
# renaming

df2.columns = ["ID", "NAME", "AGE", "COUNTRY" , "GENDER" , "INCOME"]
df2.columns
df2.rename(columns={"INCOME": "Salary"})
df2.rename(index={0: "zero"})


#sorting

df2.sort_values("INCOME" , ascending=False)
df2.sort_values(["INCOME", "AGE"])

df2.sort_index()
sorted_valu = df2.sort_values(["INCOME", "AGE"])
#reset index
print(sorted_valu)

sorted_valu.reset_index()
sorted_valu.reset_index(drop=True)
# Out:
#     ID          NAME   AGE COUNTRY   GENDER   INCOME
# 9    9   Carlos Ruiz   NaN  Mexico     Male  45000.0
# 3    3          Alex   NaN     USA  Unknown  47000.0
# 5    5        Li Wei  27.0   China     Male  51000.0
# 0    1      John Doe  29.0     USA     Male  55000.0
# 1    1      John Doe  29.0     USA     Male  55000.0
# 10  10   Emily Davis  31.0     USA      NaN  58000.0
# 8    8    Rachel Lee  29.0     USA   Female  62000.0
# 2    2    Jane Smith   NaN  Canada   Female  62000.0
# 7    7    Ahmed Khan  38.0     NaN     Male  68000.0
# 6    6           NaN  45.0   India   Female  73000.0
# 4    4  Maria Garcia  34.0   Spain   Female      NaN
#     ID          NAME   AGE COUNTRY   GENDER   INCOME
# 0    9   Carlos Ruiz   NaN  Mexico     Male  45000.0
# 1    3          Alex   NaN     USA  Unknown  47000.0
# 2    5        Li Wei  27.0   China     Male  51000.0
# 3    1      John Doe  29.0     USA     Male  55000.0
# 4    1      John Doe  29.0     USA     Male  55000.0
# ...

# %%
#ranking
df2["INCOME"].rank(ascending=False , method="dense")
df2["INCOME"].rank(ascending=False , method="dense")
# Out:
# 0     5.0
# 1     5.0
# 2     3.0
# 3     7.0
# 4     NaN
# 5     6.0
# 6     1.0
# 7     2.0
# 8     3.0
# 9     8.0
# 10    4.0
# Name: INCOME, dtype: float64

# %%
# Reorder
df2[["ID", "NAME", "AGE", "INCOME", "GENDER"]]
# Out:
#     ID          NAME   AGE   INCOME   GENDER
# 0    1      John Doe  29.0  55000.0     Male
# 1    1      John Doe  29.0  55000.0     Male
# 2    2    Jane Smith   NaN  62000.0   Female
# 3    3          Alex   NaN  47000.0  Unknown
# 4    4  Maria Garcia  34.0      NaN   Female
# 5    5        Li Wei  27.0  51000.0     Male
# 6    6           NaN  45.0  73000.0   Female
# 7    7    Ahmed Khan  38.0  68000.0     Male
# 8    8    Rachel Lee  29.0  62000.0   Female
# 9    9   Carlos Ruiz   NaN  45000.0     Male
# 10  10   Emily Davis  31.0  58000.0      NaN

# %%
# Grouping & Aggregation
df3 = df2.copy()
df3
df3.columns = ["id", "name", "age", "country", "gender", "income"]
df3.groupby("country")["income"].mean()
df3.groupby("gender")["income"].max() 
df3.groupby("gender")["income"].agg(["mean", "max"])
df3.groupby("gender")["income"].agg(avg_salary="mean", max_value= "max")
# Out:
#            avg_salary  max_value
# gender
# Female   65666.666667    73000.0
# Male     54800.000000    68000.0
# Unknown  47000.000000    47000.0

# %%
df3.groupby("country").agg({
    "age": "mean",
    "income": "max"
})

df3.groupby("country").agg(
    avg_salary=("age", "mean"),
    max_val=("income", "max")
)
# Out:
#          avg_salary  max_val
# country
# Canada          NaN  62000.0
# China          27.0  51000.0
# India          45.0  73000.0
# Mexico          NaN  45000.0
# Spain          34.0      NaN
# USA            29.5  62000.0

# %%
#melt and pivot

df = pd.DataFrame({
    "country": ["USA", "USA", "India", "India"],
    "year": [2020, 2021, 2020, 2021],
    "sales": [100, 120, 90, 110],
    "profit": [20, 25, 18, 22]
})
print(df)
melted= df.melt(id_vars=["country", "year"], value_vars=["sales", "profit"], var_name="metric", value_name="value in lac")
melted
# Out:
#   country  year  sales  profit
# 0     USA  2020    100      20
# 1     USA  2021    120      25
# 2   India  2020     90      18
# 3   India  2021    110      22
#   country  year  metric  value in lac
# 0     USA  2020   sales           100
# 1     USA  2021   sales           120
# 2   India  2020   sales            90
# 3   India  2021   sales           110
# 4     USA  2020  profit            20
# 5     USA  2021  profit            25
# 6   India  2020  profit            18
# 7   India  2021  profit            22

# %%
originaol = melted.pivot(
    index=["country", "year"],   # cols that become the NEW row index - can't for just country
    columns="metric",            # col whose unique values will become the cols
    values="value in lac"    # cowill fl whose values ill the new df
)
originaol
# Out:
# metric        profit  sales
# country year
# India   2020      18     90
#         2021      22    110
# USA     2020      20    100
#         2021      25    120

# %%
# Merging & Joining
df_customers = pd.DataFrame({
    "customer_id": [1, 2, 3, 4],
    "name": ["Adam", "Bob", "Charlie", "Dave"]
})

df_orders = pd.DataFrame({
    "order_id": [101, 102, 103, 104],
    "customer_id": [2, 1, 4, 5],
    "amount": [250, 120, 300, 180]
})
pd.merge(df_customers, df_orders, on="customer_id")                  # Inner Join
pd.merge(df_customers, df_orders, on="customer_id", how="left")      # Left Join
pd.merge(df_customers, df_orders, on="customer_id", how="right")     # Right Join
pd.merge(df_customers, df_orders, on="customer_id", how="outer")     # Outer Join
# Out:
#    customer_id     name  order_id  amount
# 0            1     Adam     102.0   120.0
# 1            2      Bob     101.0   250.0
# 2            3  Charlie       NaN     NaN
# 3            4     Dave     103.0   300.0
# 4            5      NaN     104.0   180.0

# %%
# Concatenation
df1 = pd.DataFrame({
    "id": [1, 2, 3],
    "name": ["Adam", "Bob", "Charlie"]
})

df2 = pd.DataFrame({
    "id": [4, 5, 6],
    "name": ["David", "Eva", "Frank"]
})

pd.concat([df1,df2])
pd.concat([df1,df2], axis=1)
# Out:
#    id     name  id   name
# 0   1     Adam   4  David
# 1   2      Bob   5    Eva
# 2   3  Charlie   6  Frank

# %%
#basic visulazation

df2.hist()
# Out:
# array([[<Axes: title={'center': 'id'}>]], dtype=object)

# %%
df.plot(kind='scatter', x='country', y='sales')
# Out:
# <Axes: xlabel='country', ylabel='sales'>
